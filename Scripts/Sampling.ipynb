# %%
load("student_survey.RData")

# %%
summary(population)
# Out:
#       Course      Handed        Sex          Verbal           Age
#   Social :539   left :150   female:701   Min.   :300.0   Min.   :17.67
#  Business:192   right:979   male  :428   1st Qu.:540.0   1st Qu.:19.08
#  Natural :398                            Median :590.0   Median :19.67
#                                          Mean   :588.8   Mean   :20.37
#                                          3rd Qu.:640.0   3rd Qu.:20.67
#                                          Max.   :800.0   Max.   :74.17
#                                          NA's   :131     NA's   :6

# %%
(random_sample = population[sample(length(population$Course),192),]) # all columns
# Out:
#      Course   Handed Sex    Verbal Age
# 1004 Business right  female 620    19.25
# 613  Natural  right  female 640    20.00
# 93   Natural  right  male   660    20.25
# 50    Social  left   female 560    18.92
# 728   Social  right  male   590    20.67
# 894   Social  left   female 420    20.17
# 47    Social  right  male    NA    26.33
# 791   Social  right  male   670    20.92
# 191   Social  right  female 600    18.92
# 967  Business right  female 620    18.75
# 311   Social  right  female 560    21.42
# 881   Social  right  female  NA    20.00
# 655  Natural  right  female 630    18.83
# 104  Natural  right  female 500    19.42
# 702  Business right  male   540    18.33
# 367   Social  right  male   540       NA
# 208   Social  right  female 560    18.83
# 101  Natural  left   female 630    18.92
# 899   Social  right  female  NA    20.08
# 417  Natural  right  female 680    19.33
# 585   Social  right  female 550    21.75
# 133  Natural  right  male   540    18.58
# 671  Natural  right  female 600    19.50
# 690  Business right  male   680    21.92
# 644  Natural  right  male    NA    20.67
# 17    Social  right  female 630    18.50
# 489  Natural  right  female 620    19.33
# 151  Natural  right  male   490    19.92
# 504  Natural  right  male   660    19.00
# 1076 Business right  female 590    18.75
# ⋮    ⋮        ⋮      ⋮      ⋮      ⋮
# 1103 Business right  male   570    19.50
# 487  Natural  right  female 620    19.92
# 332   Social  right  male   550    18.58
# 689  Business right  male   600    21.67
# 424  Natural  right  female 640    18.42
# 888   Social  right  female 420    18.75
# 179  Natural  right  female 560    19.17
# 257   Social  right  female 690    18.42
# 1101 Business right  female 520    19.92
# 413  Business right  male   610    20.17
# 680  Business left   male   500    19.08
# 896   Social  right  female 680    21.00
# 829   Social  right  female 520    26.17
# 66    Social  left   female 600    19.92
# 509   Social  right  female 630    18.75
# 1002 Business right  female 650    19.92
# 1120  Social  right  female  NA    19.67
# 350   Social  right  male   670    19.17
# 643  Natural  right  male   540    19.42
# 137  Natural  right  female 670    19.50
# 305   Social  right  female 510    20.17
# 331   Social  right  female 480    19.08
# 497  Natural  right  female 560    20.58
# 134  Natural  right  female 520    22.08
# 444  Natural  right  male   640    21.58
# 359   Social  right  female 590    19.92
# 616  Natural  right  male   600    20.25
# 626  Natural  right  female 750    20.50
# 110  Natural  right  female 560    19.50
# 96   Natural  right  male   620    19.25

# %%
(random_sample_percent = 100*prop.table(table(random_sample$Handed)))
# Out:
#    left   right
# 10.9375 89.0625

# %%
(pop_percent = 100*prop.table(table(population$Handed)))
# Out:
#     left    right
# 13.28609 86.71391

# %%
barplot(rbind(pop_percent,random_sample_percent), beside=T, col=c(0,1),legend.text=T,xlab="Handedness",ylab="Percent in Group",args.legend=list(x="topleft"))
# Out:
# plot without title

# %%
random_sample_percent = 100*summary(random_sample$Handed)/length(random_sample$Handed)
pop_percent = 100*summary(population$Handed)/length(population $Handed)
par(mfrow=c(1,2))
pie(pop_percent,labels=paste(c("left=","right="),round(pop_percent,0),"%"),main="Population")
pie(random_sample_percent,labels=paste(c("left=","right="),round(random_sample_percent,0),"%"),main="Random Sample")
# Out:
# Plot with title “Random Sample”

# %%
random_sample_percent = 100*summary(random_sample$Sex)/length(random_sample$Sex)
pop_percent = 100*summary(population$Sex)/length(population$Sex)
par(mfrow=c(1,2))
pie(pop_percent,labels=paste(c("Female=","Male="),round(pop_percent,0),"%"),main="Population")
pie(random_sample_percent,labels=paste(c("Female=","Male="),round(random_sample_percent,0),"%"),main="Random Sample")
# Out:
# Plot with title “Random Sample”

# %%
summary(population$Verbal) 
summary(random_sample$Verbal)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.    NA's
#   300.0   540.0   590.0   588.8   640.0   800.0     131
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.    NA's
#   400.0   540.0   600.0   590.1   640.0   760.0      15

# %%
summary(population$Age) 
summary(random_sample$Age)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.    NA's
#   17.67   19.08   19.67   20.37   20.67   74.17       6
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.    NA's
#   18.00   19.08   19.67   20.44   20.58   74.17       1
